# %%
import pandas as pd
import numpy as np

# %%
eco=pd.read_csv("efw_cc.csv")
eco
# Out:
#       year ISO_code               countries  ECONOMIC FREEDOM   rank  \
# 0     2016      ALB                 Albania              7.54   34.0
# 1     2016      DZA                 Algeria              4.99  159.0
# 2     2016      AGO                  Angola              5.17  155.0
# 3     2016      ARG               Argentina              4.84  160.0
# 4     2016      ARM                 Armenia              7.57   29.0
# 5     2016      AUS               Australia              7.98   10.0
# 6     2016      AUT                 Austria              7.58   27.0
# 7     2016      AZE              Azerbaijan              6.49  106.0
# 8     2016      BHS                 Bahamas              7.34   49.0
# 9     2016      BHR                 Bahrain              7.56   30.0
# 10    2016      BGD              Bangladesh              6.30  120.0
# 11    2016      BRD                Barbados              6.43  111.0
# 12    2016      BLR                 Belarus              6.23  123.0
# ...

# %%
np.sum(eco.isnull())
# Out:
# year                                     0
# ISO_code                                 0
# countries                                0
# ECONOMIC FREEDOM                       723
# rank                                   723
# quartile                               723
# 1a_government_consumption              589
# 1b_transfers                           960
# 1c_gov_enterprises                     646
# 1d_top_marg_tax_rate                  1047
# 1_size_government                      647
# 2a_judicial_independence              1553
# 2b_impartial_courts                   1179
# 2c_protection_property_rights         1129
# 2d_military_interference              1186
# 2e_integrity_legal_system             1153
# 2f_legal_enforcement_contracts        1361
# 2g_restrictions_sale_real_property    1384
# 2h_reliability_police                 2071
# 2i_business_costs_crime               2071
# 2j_gender_adjustment                    66
# 2_property_rights                      755
# ...

# %%
economic=eco.drop('rank',1)
economic
# Out:
#       year ISO_code               countries  ECONOMIC FREEDOM  quartile  \
# 0     2016      ALB                 Albania              7.54       1.0
# 1     2016      DZA                 Algeria              4.99       4.0
# 2     2016      AGO                  Angola              5.17       4.0
# 3     2016      ARG               Argentina              4.84       4.0
# 4     2016      ARM                 Armenia              7.57       1.0
# 5     2016      AUS               Australia              7.98       1.0
# 6     2016      AUT                 Austria              7.58       1.0
# 7     2016      AZE              Azerbaijan              6.49       3.0
# 8     2016      BHS                 Bahamas              7.34       2.0
# 9     2016      BHR                 Bahrain              7.56       1.0
# 10    2016      BGD              Bangladesh              6.30       3.0
# 11    2016      BRD                Barbados              6.43       3.0
# ...

# %%
np.sum(economic.isnull())
# Out:
# year                                     0
# ISO_code                                 0
# countries                                0
# ECONOMIC FREEDOM                       723
# quartile                               723
# 1a_government_consumption              589
# 1b_transfers                           960
# 1c_gov_enterprises                     646
# 1d_top_marg_tax_rate                  1047
# 1_size_government                      647
# 2a_judicial_independence              1553
# 2b_impartial_courts                   1179
# 2c_protection_property_rights         1129
# 2d_military_interference              1186
# 2e_integrity_legal_system             1153
# 2f_legal_enforcement_contracts        1361
# 2g_restrictions_sale_real_property    1384
# 2h_reliability_police                 2071
# 2i_business_costs_crime               2071
# 2j_gender_adjustment                    66
# 2_property_rights                      755
# 3a_money_growth                        644
# ...

# %%
economic.describe()
# Out:
#               year  ECONOMIC FREEDOM     quartile  1a_government_consumption  \
# count  3726.000000       3003.000000  3003.000000                3137.000000
# mean   2001.347826          6.519640     2.497835                   5.862426
# std      12.735125          1.133638     1.118963                   2.270241
# min    1970.000000          1.970000     1.000000                   0.000000
# 25%    1995.000000          5.855000     1.000000                   4.450000
# 50%    2005.000000          6.680000     3.000000                   6.082353
# 75%    2011.000000          7.350000     3.000000                   7.571360
# max    2016.000000          9.190000     4.000000                  10.000000
#
#        1b_transfers  1c_gov_enterprises  1d_top_marg_tax_rate  \
# count   2766.000000         3080.000000           2679.000000
# mean       7.672901            5.737987              5.813177
# std        2.138957            3.242377              2.654083
# ...

# %%
economic2=economic.drop('2h_reliability_police',1)
economy=economic2.drop('2i_business_costs_crime',1)

# %%
economy['ECONOMIC FREEDOM']=economy['ECONOMIC FREEDOM'].fillna((economy['ECONOMIC FREEDOM'].mean()))
economy['quartile']=economy['quartile'].fillna((economy['quartile'].mean()))
economy['1a_government_consumption']=economy['1a_government_consumption'].fillna((economy['1a_government_consumption'].mean()))
economy['1b_transfers']=economy['1b_transfers'].fillna((economy['1b_transfers'].mean()))
economy['1c_gov_enterprises']=economy['1c_gov_enterprises'].fillna((economy['1c_gov_enterprises'].mean()))
economy['1d_top_marg_tax_rate']=economy['1d_top_marg_tax_rate'].fillna((economy['1d_top_marg_tax_rate'].mean()))
economy['1_size_government']=economy['1_size_government'].fillna((economy['1_size_government'].mean()))
economy['2a_judicial_independence']=economy['2a_judicial_independence'].fillna((economy['2a_judicial_independence'].mean()))
economy['2b_impartial_courts']=economy['2b_impartial_courts'].fillna((economy['2b_impartial_courts'].mean()))
economy['2c_protection_property_rights']=economy['2c_protection_property_rights'].fillna((economy['2c_protection_property_rights'].mean()))
economy['2d_military_interference']=economy['2d_military_interference'].fillna((economy['2d_military_interference'].mean()))
economy['2e_integrity_legal_system']=economy['2e_integrity_legal_system'].fillna((economy['2e_integrity_legal_system'].mean()))
economy['2f_legal_enforcement_contracts']=economy['2f_legal_enforcement_contracts'].fillna((economy['2f_legal_enforcement_contracts'].mean()))
economy['2g_restrictions_sale_real_property']=economy['2g_restrictions_sale_real_property'].fillna((economy['2g_restrictions_sale_real_property'].mean()))
economy['2j_gender_adjustment']=economy['2j_gender_adjustment'].fillna((economy['2j_gender_adjustment'].mean()))
economy['2_property_rights']=economy['2_property_rights'].fillna((economy['2_property_rights'].mean()))
economy['3a_money_growth']=economy['3a_money_growth'].fillna((economy['3a_money_growth'].mean()))
economy['3b_std_inflation']=economy['3b_std_inflation'].fillna((economy['3b_std_inflation'].mean()))
economy['3c_inflation']=economy['3c_inflation'].fillna((economy['3c_inflation'].mean()))
economy['3d_freedom_own_foreign_currency']=economy['3d_freedom_own_foreign_currency'].fillna((economy['3d_freedom_own_foreign_currency'].mean()))
economy['3_sound_money']=economy['3_sound_money'].fillna((economy['3_sound_money'].mean()))
economy['4a_tariffs']=economy['4a_tariffs'].fillna((economy['4a_tariffs'].mean()))
economy['4b_regulatory_trade_barriers']=economy['4b_regulatory_trade_barriers'].fillna((economy['4b_regulatory_trade_barriers'].mean()))
economy['4c_black_market']=economy['4c_black_market'].fillna((economy['4c_black_market'].mean()))
economy['4d_control_movement_capital_ppl']=economy['4d_control_movement_capital_ppl'].fillna((economy['4d_control_movement_capital_ppl'].mean()))
economy['4_trade']=economy['4_trade'].fillna((economy['4_trade'].mean()))
economy['5a_credit_market_reg']=economy['5a_credit_market_reg'].fillna((economy['5a_credit_market_reg'].mean()))
economy['5b_labor_market_reg']=economy['5b_labor_market_reg'].fillna((economy['5b_labor_market_reg'].mean()))
economy['5c_business_reg']=economy['5c_business_reg'].fillna((economy['5c_business_reg'].mean()))
economy['5_regulation']=economy['5_regulation'].fillna((economy['5_regulation'].mean()))

np.sum(economy.isnull())
# Out:
# year                                  0
# ISO_code                              0
# countries                             0
# ECONOMIC FREEDOM                      0
# quartile                              0
# 1a_government_consumption             0
# 1b_transfers                          0
# 1c_gov_enterprises                    0
# 1d_top_marg_tax_rate                  0
# 1_size_government                     0
# 2a_judicial_independence              0
# 2b_impartial_courts                   0
# 2c_protection_property_rights         0
# 2d_military_interference              0
# 2e_integrity_legal_system             0
# 2f_legal_enforcement_contracts        0
# 2g_restrictions_sale_real_property    0
# 2j_gender_adjustment                  0
# 2_property_rights                     0
# 3a_money_growth                       0
# 3b_std_inflation                      0
# 3c_inflation                          0
# 3d_freedom_own_foreign_currency       0
# ...

# %%
from scipy import stats
z = np.abs(stats.zscore(economy._get_numeric_data()))
print(z)
economy = economy[(z < 3).all(axis=1)]
print(economy.shape)
# Out:
# [[1.15068680e+00 1.00275567e+00 1.49129869e+00 ... 5.97005225e-01
#   5.16479671e-01 2.41295854e-01]
#  [1.15068680e+00 1.50324992e+00 1.49560880e+00 ... 9.09233631e-01
#   5.10808841e-01 1.23104090e+00]
#  [1.15068680e+00 1.32635541e+00 1.49560880e+00 ... 1.28379469e+00
#   1.25631881e+00 1.00675498e+00]
#  ...
#  [2.46185515e+00 3.49141974e-15 0.00000000e+00 ... 4.96334214e-15
#   1.77356226e-15 7.98394745e-16]
#  [2.46185515e+00 3.49141974e-15 0.00000000e+00 ... 4.96334214e-15
#   1.77356226e-15 7.98394745e-16]
#  [2.46185515e+00 3.49141974e-15 0.00000000e+00 ... 4.96334214e-15
#   1.77356226e-15 7.98394745e-16]]
# (3076, 33)

# %%
# source : kaggle.com
