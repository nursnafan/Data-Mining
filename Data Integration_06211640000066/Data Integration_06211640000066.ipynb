# %%
import pandas as pd
import numpy as np

# %%
#Source = foxsports.com

# %%
statistic1=pd.read_csv("Defensive_Stats1.csv")
statistic2=pd.read_csv("Defensive_Stats2.csv")
print (statistic1)
print (statistic2)
discipline_statistics=pd.merge(statistic1,statistic2,on='Name')
discipline_statistics
# Out:
#                         Name  Club  Games  Games Started  Minutes  Crosses  \
# 0             Holebas  Jose    WAT     23             22     1272      183
# 1          Lerma  Jefferson    BOU     20             19     1129        6
# 2                Shaw  Luke    MUN     20             20     1062       59
# 3         Milivojevic  Luka    CRY     26             26     1530      159
# 4             Schar  Fabian    NEW     14             12     1071        8
# 5         Snodgrass  Robert    WHU     25             18     1196      126
# 6            Bardsley  Phil    BUR     13             13      952       31
# 7              Arter  Harry     CC     21             20     1001       18
# 8             Xhaka  Granit    ARS     22             22     1139       92
# 9             Ritchie  Matt    NEW     24             23     1289      175
# 10         Hojbjerg  Pierre    SOU     19             19     1067       24
# ...
